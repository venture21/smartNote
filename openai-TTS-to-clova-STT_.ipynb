# %%
# !pip install --upgrade google-cloud-texttospeech
# Out:
# Collecting google-cloud-texttospeech
#   Downloading google_cloud_texttospeech-2.31.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (2.26.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-texttospeech) (2.41.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-texttospeech) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-texttospeech) (5.29.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (1.75.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-texttospeech) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-texttospeech) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-texttospeech) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-texttospeech) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-texttospeech) (0.6.1)
# Downloading google_cloud_texttospeech-2.31.0-py3-none-any.whl (191 kB)
# Installing collected packages: google-cloud-texttospeech
# Successfully installed google-cloud-texttospeech-2.31.0
# Requirement already satisfied: vertexai in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (1.71.1)
# Requirement already satisfied: google-cloud-aiplatform==1.71.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform[all]==1.71.1->vertexai) (1.71.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.26.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.41.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (5.29.5)
# Requirement already satisfied: packaging>=14.3 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (25.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.14.2)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.1.2)
# Requirement already satisfied: pydantic<3 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.11.10)
# Requirement already satisfied: docstring-parser<1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.75.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.7.1)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in c:\users\park0\miniconda3\envs\smartnote\lib\site-packages (from shapely<3.0.0dev->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.3.4)
# WARNING: google-cloud-aiplatform 1.71.1 does not provide the extra 'all'

# %%
from dotenv import load_dotenv

# .env 파일에서 환경변수 로드
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 구글 딥리서치의 결과를 바탕으로 가상 회의록을 생성해보자.
#
# 가상 회의록을 생성하는 순서는 다음과 같다.
# STEP 1. 참조 파일을 바탕으로 1~4차 회의록 내용을 생성.
# STEP 2. gemini-2.5-pro tts용 contents 스타일로 변환
# STEP 3. 회의록 각 차수에 맞게 나눈다.
# STEP 4. 각 차수별 오디오 파일을 생성한다.
#
# 참조파일 : aiNote_report.txt

# %% [markdown]
# ### STEP 1. 참조 파일을 바탕으로 1~4차 회의록 내용을 생성.

# %%
from google import genai
from google.genai import types

# 여기에 자신의 API 키를 설정하거나 gcloud auth application-default login 명령으로 인증하세요.
client = genai.Client()

# 텍스트 파일을 불러올 로컬 PC의 전체 경로를 지정합니다.
file_path = "./data/aiNote_report.txt"

# 파일을 바이너리(binary) 읽기 모드('rb')로 엽니다.
with open(file_path, "rb") as f:
    file_bytes = f.read()

# 사용할 모델을 설정합니다.
model_name = "gemini-2.5-pro"

prompt = """가상의 회의록을 만들려고 합니다. 
        주제는 AI 회의록 정리 및 요약, Q&A 서비스 입니다. 
        이에 대한 세부 내용은 다음과 같습니다. 
        이 내용을 바탕으로 4번에 걸친 가상 회의록을 만들려고 합니다. 
        가상 회의록에 참여자는 4명이고, 4번의 회의를 통해 기획이 정리되는 과정을 대화 형태로 만들어주면 돼.
        대화의 내용에 안부 인사나 날씨, 오늘 출근 하면서 있었던 일들, 중간에 휴대폰이 울려서 전화를 받고 
        바로 끊는 것과 같은 대한 잡담과 같은 내용도 추가해줘.
        """

# --- 주요 변경 사항 ---
# 'types.Part.from_data' 대신 'types.Part.from_bytes'를 사용합니다.
# Base64 인코딩 과정 없이 파일에서 읽은 바이트(file_bytes)를 직접 전달합니다.
response = client.models.generate_content(
    model=model_name,
    contents=[
        prompt,
        types.Part.from_bytes(
            data=file_bytes,  # 파일에서 읽은 원본 바이트 데이터를 사용합니다.
            mime_type="text/plain",
        ),
    ],
)

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 네, 알겠습니다. 제공해주신 상세한 기획안을 바탕으로, 4명의 참여자가 4번의 회의를 거쳐 'AI 회의록 정리 및 요약, Q&A 서비스' 기획을 발전시키는 과정을 가상 회의록 형태로 작성해 드리겠습니다. 잡담과 자연스러운 대화 흐름을 포함하여 생동감 있게 구성하겠습니다.
#
# ---
#
# ### 등장인물
#
# *   **김민준 팀장 (PM):** 프로젝트를 총괄하는 프로덕트 매니저. 논리적이고 목표 지향적이다.
# *   **이정훈 수석 (개발):** 기술적인 관점에서 실현 가능성과 구조를 검토하는 리드 개발자. 현실적이고 신중하다.
# *   **박서연 디자이너 (UX/UI):** 사용자 경험과 디자인을 책임진다. 사용자 관점에서 문제를 제기하고 아이디어를 낸다.
# *   **최지호 매니저 (사업/마케팅):** 시장 분석, 경쟁 환경, 수익 모델을 담당한다. 시장의 흐름과 비즈니스 기회에 민감하다.
#
# ---
#
# ### 1차 회의록: 프로젝트 킥오프 및 시장 분석
#
# **회의명:** 신규 AI 회의 인텔리전스 플랫폼 킥오프 미팅
# **일시:** 2023년 10월 23일 (월) 10:00 AM
# **장소:** 본사 1회의실
# **참석자:** 김민준 팀장, 이정훈 수석, 박서연 디자이너, 최지호 매니저
#
# **(회의 시작)**
#
# **김민준 팀장:** 다들 좋은 아침입니다. 주말은 잘 보내셨어요? 오늘 아침에 비가 와서 그런지 차가 엄청 막히더라고요. 지각할 뻔했습니다.
#
# **최지호 매니저:** 저도요. 버스에 사람이 어찌나 많던지. 그래도 커피 한 잔 하니 정신이 좀 드네요.
#
# **박서연 디자이너:** 전 다행히 지하철 타고 와서 괜찮았어요. 자, 다들 커피도 있으니 시작해볼까요?
#
# **김민준 팀장:** 네, 좋습니다. 오늘부터 우리가 함께 만들어갈 신규 프로젝트, 가칭 'AI 회의 인텔리전스 플랫폼'에 대한 킥오프 미팅을 시작하겠습니다. 제가 공유 드린 전략 분석 보고서는 다들 읽어보셨죠?
#
# **이정훈 수석:** 네, 어제 밤에 정독했습니다. 분량이 꽤 되던데요. (웃음) 시장 분석이 아주 상세해서 놀랐습니다.
#
# **김민준 팀장:** 그렇죠? 보고서의 핵심 논지, '단순 녹취를 넘어 인텔리전스로의 진화'라는 말이 딱 와닿았어요. 이제 STT 정확도만으로는 승부할 수 없는 시장이 된 거죠. 우리의 목표는 단순한 받아쓰기 셔틀이 아니라, 회의에서 '통찰력'을 뽑아주는 진정한 '인텔리전스' 플랫폼을 만드는 겁니다.
#
# **최지호 매니저:** 맞습니다. 특히 국내 시장 분석 파트가 인상 깊었어요. 네이버 '클로바노트'가 '한국어라는 해자(moat)'를 아주 깊게 파놓은 상황에서, 우리가 단순히 '한국어 인식이 더 정확해요'라고 외치는 건 자살행위나 다름없죠.
#
# **박서연 디자이너:** 저도 그 부분에 공감해요. 클로바노트를 쓰는 친구들 보면 정확도 자체에는 이미 만족하고 있더라고요. 오히려 UI가 좀 더 편했으면 좋겠다거나, 회의 끝나고 바로 할 일을 정리해줬으면 좋겠다는 식의 '워크플로우'에 대한 불만이 많았어요. 보고서에서 말하는 '인텔리전스 및 워크플로우 계층'을 우리가 어떻게 설계하느냐가 관건이겠네요.
#
# **이정훈 수석:** 기술적인 관점에서도 시사하는 바가 큽니다. OpenAI의 Whisper 같은 좋은 오픈소스 모델도 있고, 클라우드 업체들 API 성능도 상향 평준화됐죠. 굳이 우리가 STT 엔진 자체를 밑바닥부터 개발하느라 리소스를 낭비할 필요가 없다는 뜻이니까요. 핵심은 변환된 텍스트를 가지고 뭘 할 거냐, 즉 후처리 로직과 AI 모델링에 집중해야 한다는 거죠.
#
# **김민준 팀장:** 모두 정확히 짚어주셨습니다. 그래서 첫 회의인 오늘, 다 같이 큰 그림에 대한 공감대를 형성하고 싶었어요. 우리는 단순히 또 하나의 클로바노트 아류작을 만들려는 게 아닙니다. 클로바노트가 선점한 시장에서 우리만의 차별화된 가치를 찾아야 합니다.
#
# **최지호 매니저:** 비토(VITO)가 '통화 녹음'에 집중하거나, 다글로가 '유튜브 스크립트'를 파고든 것처럼 우리도 명확한 타겟이나 틈새를 찾아야겠군요.
#
# **김민준 팀장:** 맞습니다. 그래서 다음 회의 전까지 각자 고민해올 부분을 좀 드릴게요. 정훈 수석님은 보고서의 '기본 토대 기능' 파트를 중심으로, 우리가 MVP(최소 기능 제품)로 가져갈 기술 스택과 STT 엔진 선정(자체/외부 API)에 대한 장단점을 검토해주세요.
#
# **이정훈 수석:** 알겠습니다. 비용과 개발 공수, 정확도 측면에서 비교 분석해보겠습니다.
#
# **김민준 팀장:** 서연 디자이너님은 경쟁 서비스들, 특히 Fathom이나 tl;dv 같은 글로벌 서비스들의 UX를 좀 더 깊게 분석해주시고, 사용자가 회의록을 가지고 어떤 '워크플로우'를 거치는지에 대한 가설을 세워주세요.
#
# **박서연 디자이너:** 네, 좋습니다. 특히 회의 내용을 공유하고 협업하는 과정에 집중해서 들여다볼게요.
#
# **김민준 팀장:** 그리고 지호 매니저님은 보고서의 '글로벌 시장' 파트와 '수익화 전략'을 중심으로, 우리가 어떤 시장 포지션을 취해야 할지, 예를 들어 '프리미엄 파괴자'가 될지, '수직적 전문가'가 될지 전략 방향성에 대한 의견을 정리해주세요.
#
# **최지호 매니저:** 재밌는 과제네요. Fathom의 파격적인 무료 정책이 굉장히 인상 깊었는데, 그 비즈니스 모델을 좀 더 파봐야겠습니다.
#
# **김민준 팀장:** 좋습니다. 그럼 다음 회의는 이번 주 금요일 오전에 하죠. 오늘 나온 이야기들을 바탕으로 각자 고민한 내용들을 공유하면서 구체적인 방향을 잡아봅시다. 다들 수고하셨습니다.
#
# **(회의 종료)**
#
# ---
#
# ### 2차 회의록: 경쟁사 심층 분석 및 핵심 기능 정의
#
# **회의명:** AI 회의 플랫폼 경쟁사 분석 및 핵심 기능 논의
# **일시:** 2023년 10월 27일 (금) 10:30 AM
# **장소:** 온라인 (Zoom)
# **참석자:** 김민준 팀장, 이정훈 수석, 박서연 디자이너, 최지호 매니저
#
# **(회의 시작)**
#
# **박서연 디자이너:** 다들 들어오셨네요. 안녕하세요! 재택근무하니 출근 시간 아껴서 너무 좋아요.
#
# **김민준 팀장:** 서연님 좋으시겠어요. 전 오늘 아이 유치원 데려다주고 오느라 정신이 하나도 없었네요. (웃음) 자, 그럼 2차 회의 시작하겠습니다. 지난번에 각자 맡은 부분들 잘 고민해오셨죠? 먼저 정훈 수석님, STT 엔진은 어떻게 보셨어요?
#
# **이정훈 수석:** 네, 결론부터 말씀드리면 MVP 단계에서는 외부 API를 활용하는 게 압도적으로 유리합니다. 자체 엔진 개발은 시간, 비용, 인력 모든 면에서 비효율적이에요. 현재로서는 OpenAI의 Whisper API나 구글, 네이버 클라우드의 STT API가 가장 유력한 후보입니다. 특히 Whisper는 한국어 정확도도 상당히 높게 나와서, 이걸 기반으로 우리만의 후처리 로직을 더하는 방향으로 가는 게 맞아 보입니다.
#
# **김민준 팀장:** 명쾌하네요. 우리 핵심은 STT 자체가 아니라 인텔리전스 계층이니까요. 좋은 판단입니다. 그럼 서연님은 UX 분석 어떠셨어요?
#
# **박서연 디자이너:** Fathom이랑 tl;dv를 직접 써봤는데, 정말 감탄했어요. 그냥 '회의 녹화 앱'이 아니더라고요. 회의가 끝나자마자 자동으로 요약본이 생성되고, 중요한 부분을 영상 클립으로 만들어서 바로 슬랙(Slack)에 공유할 수 있는 경험이 정말 강력했어요. 사용자가 회의록을 '정리'하게 만드는 게 아니라, '활용'하게 만드는 데 초점을 맞춘 거죠. 우리의 워크플로우도 이 방향으로 가야 해요. '회의 → 기록 → 요약 → 실행 항목 도출 → 협업 툴 연동' 이 과정이 물 흐르듯 이어져야 합니다.
#
# **최지호 매니저:** 서연님 말씀에 전적으로 동감합니다. 제가 분석한 시장 포지셔닝 전략과도 일맥상통해요. 글로벌 시장은 두 갈래로 나뉘어 있어요. Fathom처럼 공격적인 무료 플랜으로 시장을 장악하는 '제품 주도 성장(PLG) 파괴자'와, Gong처럼 세일즈팀에 특화된 고가 솔루션인 '수직적 전문가'. 우리가 지금 Gong처럼 되기엔 특정 산업에 대한 깊이와 영업 조직이 부족합니다.
#
# **(그때 최지호 매니저의 휴대폰이 '징-' 하고 울린다.)**
#
# **최지호 매니저:** 어, 죄송합니다. 잠시만요. (휴대폰을 보더니) 네, 아니에요. 회의 중이라 나중에 연락드릴게요. ... 죄송합니다. 이어서 말씀드리면, 우리에게 가장 현실적이고 파급력 있는 전략은 '더 나은 프리미엄 파괴자'가 되는 겁니다. Fathom처럼 녹음/녹취는 관대하게 무료로 풀어서 사용자를 모으고, 그들이 정말 돈을 내고 싶어 할 만한 '팀 협업 기능'이나 '고급 AI 기능'에서 수익을 내는 거죠.
#
# **김민준 팀장:** '더 나은 프리미엄 파괴자'라... 흥미로운 방향성이네요. 그럼 Fathom보다 '더 나은' 점은 뭘로 가져가야 할까요?
#
# **이정훈 수석:** 보고서에 나온 '대화형 AI 챗' 기능이 강력한 무기가 될 수 있겠네요. "지난 분기에 결정된 예산안 다시 알려줘"라고 물으면 답해주는 기능이요. 이건 Fathom의 무료 플랜에는 없는 고부가가치 기능입니다. 이걸 우리 킬러 기능으로 삼는 거죠.
#
# **박서연 디자이너:** 좋아요! 사용자가 과거 회의록을 일일이 뒤지는 고통을 해결해줄 수 있겠네요. UX적으로도 아주 매력적인 기능이에요.
#
# **김민준 팀장:** 아주 좋은 아이디어들이네요. 그럼 방향이 어느 정도 잡히는 것 같습니다. 우리의 전략적 포지션은 '더 나은 프리미엄 파괴자'로 하고, 핵심 차별점은 '강력한 AI 챗 기능'과 '매끄러운 워크플로우 통합'으로 가져가는 걸로요. 그럼 이 방향성에 맞춰 다음 회의에서는 구체적인 MVP 기능 리스트를 확정해봅시다. 보고서 3부의 '기능 구현 로드맵' 표를 기준으로 어떤 걸 넣고 뺄지 결정하죠. 다들 수고 많으셨습니다!
#
# **(회의 종료)**
#
# ---
#
# ### 3차 회의록: MVP 기능 정의 및 우선순위 결정
#
# **회의명:** AI 회의 플랫폼 MVP 기능 리스트 확정
# **일시:** 2023년 11월 1일 (수) 02:00 PM
# **장소:** 본사 3회의실 (화이트보드룸)
# **참석자:** 김민준 팀장, 이정훈 수석, 박서연 디자이너, 최지호 매니저
#
# **(회의 시작)**
#
# **김민준 팀장:** 다들 점심은 맛있게 드셨어요? 자, 그럼 지난번에 논의했던 '더 나은 프리미엄 파괴자' 전략을 기반으로, 오늘은 우리 제품의 MVP 스펙을 확정 짓는 중요한 날입니다. 제가 화이트보드에 보고서의 기능 로드맵 표를 그려놨어요. 여기서 MVP에 포함될 것과 아닌 것을 명확히 구분해보죠.
#
# **이정훈 수석:** 우선 '녹취 엔진'은 고정확도 STT, 화자 분리. 이건 기본 중의 기본이니 당연히 들어가야 하고요. 플랫폼은 우선순위를 고려해서 '웹 앱'부터 집중하는 게 맞겠습니다. 모바일 앱은 MVP 이후 단계로 미루고요.
#
# **최지호 매니저:** 동의합니다. 초기 타겟 유저들은 대부분 PC 환경에서 화상 회의를 하고 결과를 확인할 테니, 웹 앱 경험을 완벽하게 만드는 게 중요해요. Fathom도 브라우저 확장 프로그램과 웹 앱이 핵심이잖아요.
#
# **박서연 디자이너:** 맞아요. 그리고 'AI 인텔리전스' 파트가 제일 중요하겠네요. '기본 자동 요약'과 '실행 항목(Action Item) 감지'는 MVP에 반드시 포함되어야 해요. 이게 없으면 그냥 녹취 앱이랑 다를 게 없으니까요.
#
# **김민준 팀장:** 그럼 우리가 킬러 기능으로 생각했던 '대화형 AI 챗'은 어떻게 할까요? MVP에 넣기엔 개발 공수가 좀 크지 않을까요, 수석님?
#
# **이정훈 수석:** 솔직히 부담되는 건 맞습니다. 하지만 이게 우리의 핵심 차별점이라면, 아주 기본적인 버전이라도 MVP에 넣어야 한다고 생각해요. 예를 들어, 현재 보고 있는 회의록 내에서만 질문에 답해주는 수준으로 시작하는 거죠. 모든 회의록을 다 뒤지는 건 2단계로 넘기고요.
#
# **최지호 매니저:** 좋은 아이디어네요. 사용자에게 '아, 이 서비스는 내 회의 내용을 이해하고 있구나!'라는 첫인상을 주는 게 중요합니다. 마케팅 관점에서도 '회의에 질문하세요'라는 메시지는 아주 강력할 겁니다.
#
# **김민준 팀장:** 좋습니다. 그럼 '대화형 AI 챗 (단일 회의)' 기능은 MVP에 넣는 걸로. 서연님, '워크플로우' 쪽은요?
#
# **박서연 디자이너:** '링크 기반 공유'는 필수고요, 사용자가 회의를 자동으로 기록하게 하려면 '캘린더 연동(구글/아웃룩)'은 무조건 있어야 해요. 이게 없으면 사용자가 매번 수동으로 봇을 초대해야 해서 너무 불편할 거예요.
#
# **최지호 매니저:** 그럼 CRM 연동이나 슬랙, 노션 같은 협업 툴 연동은요?
#
# **김민준 팀장:** 그건 우리가 유료 플랜의 핵심 가치로 제공할 기능들이니 MVP에서는 제외하는 게 맞겠습니다. 우선 사용자가 우리 제품 자체의 가치를 느끼게 하는 데 집중해야죠. 정리하겠습니다. (화이트보드에 표시하며)
#
# **[MVP 기능 리스트]**
# *   **녹취:** 고정확도 STT (외부 API), 화자 분리
# *   **플랫폼:** 웹 앱, 브라우저 확장 프로그램 (Zoom, Google Meet)
# *   **AI:** 기본 자동 요약, 실행 항목 감지, 대화형 AI 챗 (단일 회의 한정)
# *   **워크플로우:** 캘린더 연동, 링크 기반 공유
# *   **제외:** 모바일 앱, CRM/협업 툴 연동, 고급 대화 인텔리전스, 팀 관리 기능
#
# **김민준 팀장:** 다들 이 리스트에 동의하시나요?
#
# **(전원 동의)**
#
# **김민준 팀장:** 좋습니다. 그럼 이 스펙을 기준으로 개발과 디자인을 시작하죠. 정훈 수석님은 상세 기술 설계와 개발 일정 산출을, 서연 디자이너님은 MVP 기능에 대한 와이어프레임 작업을 시작해주세요. 지호 매니저님은 이 MVP를 기반으로 구체적인 시장 진출(GTM) 전략과 가격 정책 초안을 준비해주시고요. 다음 회의 땐 각자 준비한 내용을 공유하면서 로드맵을 구체화합시다.
#
# **(회의 종료)**
#
# ---
#
# ### 4차 회의록: 개발 로드맵 확정 및 최종 점검
#
# **회의명:** AI 회의 플랫폼 개발 로드맵 확정 및 액션 아이템 점검
# **일시:** 2023년 11월 8일 (수) 03:00 PM
# **장소:** 본사 1회의실
# **참석자:** 김민준 팀장, 이정훈 수석, 박서연 디자이너, 최지호 매니저
#
# **(회의 시작)**
#
# **최지호 매니저:** 지난주에 정한 MVP 스펙으로 GTM 전략을 짜보니까 그림이 훨씬 명확해지더라고요. 역시 일단 뭐라도 정해야 일이 진행되는 것 같아요.
#
# **김민준 팀장:** 맞아요. 다들 바쁘게 일주일을 보내셨을 텐데, 진행 상황을 한 번 들어볼까요? 서연님, 와이어프레임은 좀 어떠세요?
#
# **박서연 디자이너:** 네, 화면에 공유해 드릴게요. (노트북 화면을 모니터에 연결한다) 이게 사용자가 회의를 끝내고 처음 마주하는 결과 화면이에요. 왼쪽엔 전체 스크립트, 오른쪽 상단엔 AI 요약과 Action Item, 그리고 하단에 저희의 킬러 기능인 '회의에 질문하기' 챗봇 창을 배치했어요. 사용자가 다른 화면으로 넘어가지 않고 한 곳에서 모든 정보를 확인하고 활용할 수 있도록 구성했습니다.
#
# **이정훈 수석:** 오, 구조가 아주 깔끔한데요. 저 정도 UI라면 API 연동하고 데이터 뿌려주는 건 기술적으로 문제없습니다. 저도 개발 일정을 산출해봤는데, 지난번에 확정한 MVP 스펙 기준으로는 3개월 정도면 초기 버전 출시가 가능할 것 같습니다. STT 엔진은 여러 테스트를 거친 결과, 비용과 성능을 고려했을 때 OpenAI의 Whisper API를 메인으로 사용하는 것으로 결정했습니다.
#
# **김민준 팀장:** 3개월이라, 아주 희망적인데요. 좋습니다. 지호 매니저님, 마케팅 쪽은요?
#
# **최지호 매니저:** 가격 정책은 보고서에서 제안한 '하이브리드 프리미엄' 모델로 구체화했습니다. 핵심 녹취/요약/AI챗(단일 회의)은 월 5회까지 무료로 제공해서 사용자 유입을 유도하고, 무제한 사용과 팀 기능, 그리고 향후 추가될 CRM 연동 등은 유료 플랜으로 묶는 방식입니다. 초기 사용자 확보를 위해선 서연님이 강조했던 '공유를 통한 바이럴 루프' 설계가 매우 중요할 것 같아요.
#
# **김민준 팀장:** 완벽합니다. 이제 정말 우리가 뭘 만들어야 할지, 어떻게 시장에 선보여야 할지 명확해졌네요. 그럼 오늘 회의를 통해 개발 로드맵을 최종 확정하겠습니다.
#
# **[최종 로드맵]**
# *   **1단계 (MVP, ~3개월):** 오늘 확정한 웹 앱 기반의 핵심 기능 출시. 초기 사용자 피드백 확보에 집중.
# *   **2단계 (경쟁력 확보, MVP 출시 후 6개월):** CRM 및 주요 협업 툴(슬랙, 노션) 연동 개발. 대화형 AI 챗 기능 고도화 (전체 회의록 대상 검색). 팀 관리 기능 추가. 모바일 앱 개발 착수.
# *   **3단계 (시장 차별화, 그 이후):** 감성 분석 등 고급 대화 인텔리전스 기능 도입. 산업별 맞춤형 요약 템플릿 제공.
#
# **김민준 팀장:** 이 로드맵대로 우리 프로젝트를 진행하겠습니다. 이제 각자 자리로 돌아가서 맡은 역할을 실행에 옮길 시간입니다. 정식 프로젝트명도 정해야 하고 할 일이 태산이지만, 이렇게 한 걸음씩 나아가면 분명 좋은 결과가 있을 겁니다. 다들 정말 수고 많으셨고, 앞으로 잘 부탁드립니다!
#
# **(전원 박수와 함께 회의 종료)**

# %%
with open("./data/meetingNote.txt", "w", encoding="utf-8") as f:
    # response.text의 내용을 파일에 씁니다.
    f.write(response.text)

print("\n회의록이 meetingNote.txt 파일로 저장되었습니다. 🎉")
# Out:
# 회의록이 meetingNote.txt 파일로 저장되었습니다. 🎉

# %% [markdown]
# ## STEP 2. gemini-2.5-pro tts용 contents 스타일로 변환

# %%
from google import genai
from google.genai import types

# 여기에 자신의 API 키를 설정하거나 gcloud auth application-default login 명령으로 인증하세요.
client = genai.Client()

# 텍스트 파일을 불러올 로컬 PC의 전체 경로를 지정합니다.
file_path = "./data/meetingNote.txt"

# 파일을 바이너리(binary) 읽기 모드('rb')로 엽니다.
with open(file_path, "rb") as f:
    file_bytes = f.read()

# 사용할 모델을 설정합니다.
model_name = "gemini-2.5-pro"

prompt = """
        1차,2차,3차,4차 회의록의 대화 내용을 그대로 수정 없이 나눠서 
        다음 양식을 참조하여 gemini-2.5-pro tts용 contents 스타일로 변환해줘.
        각 차수 회의록의 시작은 "[회의록 HEADER]"이라는 문자열로 시작하게 추가해줘.
        대화자명도 Speaker 1, Speaker 2형태로 변경해줘. speaker의 순서는 각 차수 회의록 안에서
        처음으로 등장하는 순서대로 1번부터 순번을 할당해줘. 출력되는 포맷은 문자열이야.
        대화 내용을 살펴보고, 대화 내용을 보조하는 내용은 맥락에 따라 대화 내용으로 변경하던지, 삭제해줘.
     
        [예시]
  
        Speaker 1: 안녕
        
        Speaker 2: 안녕하세요.    

        """

# --- 주요 변경 사항 ---
# 'types.Part.from_data' 대신 'types.Part.from_bytes'를 사용합니다.
# Base64 인코딩 과정 없이 파일에서 읽은 바이트(file_bytes)를 직접 전달합니다.
response = client.models.generate_content(
    model=model_name,
    contents=[
        prompt,
        types.Part.from_bytes(
            data=file_bytes,  # 파일에서 읽은 원본 바이트 데이터를 사용합니다.
            mime_type="text/plain",
        ),
    ],
)

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# [회의록 HEADER]
# Speaker 1: 다들 좋은 아침입니다. 주말은 잘 보내셨어요? 오늘 아침에 비가 와서 그런지 차가 엄청 막히더라고요. 지각할 뻔했습니다.
# Speaker 2: 저도요. 버스에 사람이 어찌나 많던지. 그래도 커피 한 잔 하니 정신이 좀 드네요.
# Speaker 3: 전 다행히 지하철 타고 와서 괜찮았어요. 자, 다들 커피도 있으니 시작해볼까요?
# Speaker 1: 네, 좋습니다. 오늘부터 우리가 함께 만들어갈 신규 프로젝트, 가칭 'AI 회의 인텔리전스 플랫폼'에 대한 킥오프 미팅을 시작하겠습니다. 제가 공유 드린 전략 분석 보고서는 다들 읽어보셨죠?
# Speaker 4: 네, 어제 밤에 정독했습니다. 분량이 꽤 되던데요. 시장 분석이 아주 상세해서 놀랐습니다.
# Speaker 1: 그렇죠? 보고서의 핵심 논지, '단순 녹취를 넘어 인텔리전스로의 진화'라는 말이 딱 와닿았어요. 이제 STT 정확도만으로는 승부할 수 없는 시장이 된 거죠. 우리의 목표는 단순한 받아쓰기 셔틀이 아니라, 회의에서 '통찰력'을 뽑아주는 진정한 '인텔리전스' 플랫폼을 만드는 겁니다.
# Speaker 2: 맞습니다. 특히 국내 시장 분석 파트가 인상 깊었어요. 네이버 '클로바노트'가 '한국어라는 해자(moat)'를 아주 깊게 파놓은 상황에서, 우리가 단순히 '한국어 인식이 더 정확해요'라고 외치는 건 자살행위나 다름없죠.
# Speaker 3: 저도 그 부분에 공감해요. 클로바노트를 쓰는 친구들 보면 정확도 자체에는 이미 만족하고 있더라고요. 오히려 UI가 좀 더 편했으면 좋겠다거나, 회의 끝나고 바로 할 일을 정리해줬으면 좋겠다는 식의 '워크플로우'에 대한 불만이 많았어요. 보고서에서 말하는 '인텔리전스 및 워크플로우 계층'을 우리가 어떻게 설계하느냐가 관건이겠네요.
# Speaker 4: 기술적인 관점에서도 시사하는 바가 큽니다. OpenAI의 Whisper 같은 좋은 오픈소스 모델도 있고, 클라우드 업체들 API 성능도 상향 평준화됐죠. 굳이 우리가 STT 엔진 자체를 밑바닥부터 개발하느라 리소스를 낭비할 필요가 없다는 뜻이니까요. 핵심은 변환된 텍스트를 가지고 뭘 할 거냐, 즉 후처리 로직과 AI 모델링에 집중해야 한다는 거죠.
# Speaker 1: 모두 정확히 짚어주셨습니다. 그래서 첫 회의인 오늘, 다 같이 큰 그림에 대한 공감대를 형성하고 싶었어요. 우리는 단순히 또 하나의 클로바노트 아류작을 만들려는 게 아닙니다. 클로바노트가 선점한 시장에서 우리만의 차별화된 가치를 찾아야 합니다.
# Speaker 2: 비토(VITO)가 '통화 녹음'에 집중하거나, 다글로가 '유튜브 스크립트'를 파고든 것처럼 우리도 명확한 타겟이나 틈새를 찾아야겠군요.
# Speaker 1: 맞습니다. 그래서 다음 회의 전까지 각자 고민해올 부분을 좀 드릴게요. 정훈 수석님은 보고서의 '기본 토대 기능' 파트를 중심으로, 우리가 MVP(최소 기능 제품)로 가져갈 기술 스택과 STT 엔진 선정(자체/외부 API)에 대한 장단점을 검토해주세요.
# Speaker 4: 알겠습니다. 비용과 개발 공수, 정확도 측면에서 비교 분석해보겠습니다.
# Speaker 1: 서연 디자이너님은 경쟁 서비스들, 특히 Fathom이나 tl;dv 같은 글로벌 서비스들의 UX를 좀 더 깊게 분석해주시고, 사용자가 회의록을 가지고 어떤 '워크플로우'를 거치는지에 대한 가설을 세워주세요.
# Speaker 3: 네, 좋습니다. 특히 회의 내용을 공유하고 협업하는 과정에 집중해서 들여다볼게요.
# Speaker 1: 그리고 지호 매니저님은 보고서의 '글로벌 시장' 파트와 '수익화 전략'을 중심으로, 우리가 어떤 시장 포지션을 취해야 할지, 예를 들어 '프리미엄 파괴자'가 될지, '수직적 전문가'가 될지 전략 방향성에 대한 의견을 정리해주세요.
# Speaker 2: 재밌는 과제네요. Fathom의 파격적인 무료 정책이 굉장히 인상 깊었는데, 그 비즈니스 모델을 좀 더 파봐야겠습니다.
# Speaker 1: 좋습니다. 그럼 다음 회의는 이번 주 금요일 오전에 하죠. 오늘 나온 이야기들을 바탕으로 각자 고민한 내용들을 공유하면서 구체적인 방향을 잡아봅시다. 다들 수고하셨습니다.
# [회의록 HEADER]
# Speaker 1: 다들 들어오셨네요. 안녕하세요! 재택근무하니 출근 시간 아껴서 너무 좋아요.
# Speaker 2: 서연님 좋으시겠어요. 전 오늘 아이 유치원 데려다주고 오느라 정신이 하나도 없었네요. 자, 그럼 2차 회의 시작하겠습니다. 지난번에 각자 맡은 부분들 잘 고민해오셨죠? 먼저 정훈 수석님, STT 엔진은 어떻게 보셨어요?
# Speaker 3: 네, 결론부터 말씀드리면 MVP 단계에서는 외부 API를 활용하는 게 압도적으로 유리합니다. 자체 엔진 개발은 시간, 비용, 인력 모든 면에서 비효율적이에요. 현재로서는 OpenAI의 Whisper API나 구글, 네이버 클라우드의 STT API가 가장 유력한 후보입니다. 특히 Whisper는 한국어 정확도도 상당히 높게 나와서, 이걸 기반으로 우리만의 후처리 로직을 더하는 방향으로 가는 게 맞아 보입니다.
# Speaker 2: 명쾌하네요. 우리 핵심은 STT 자체가 아니라 인텔리전스 계층이니까요. 좋은 판단입니다. 그럼 서연님은 UX 분석 어떠셨어요?
# Speaker 1: Fathom이랑 tl;dv를 직접 써봤는데, 정말 감탄했어요. 그냥 '회의 녹화 앱'이 아니더라고요. 회의가 끝나자마자 자동으로 요약본이 생성되고, 중요한 부분을 영상 클립으로 만들어서 바로 슬랙(Slack)에 공유할 수 있는 경험이 정말 강력했어요. 사용자가 회의록을 '정리'하게 만드는 게 아니라, '활용'하게 만드는 데 초점을 맞춘 거죠. 우리의 워크플로우도 이 방향으로 가야 해요. '회의 → 기록 → 요약 → 실행 항목 도출 → 협업 툴 연동' 이 과정이 물 흐르듯 이어져야 합니다.
# Speaker 4: 서연님 말씀에 전적으로 동감합니다. 제가 분석한 시장 포지셔닝 전략과도 일맥상통해요. 글로벌 시장은 두 갈래로 나뉘어 있어요. Fathom처럼 공격적인 무료 플랜으로 시장을 장악하는 '제품 주도 성장(PLG) 파괴자'와, Gong처럼 세일즈팀에 특화된 고가 솔루션인 '수직적 전문가'. 우리가 지금 Gong처럼 되기엔 특정 산업에 대한 깊이와 영업 조직이 부족합니다.
# Speaker 4: 어, 죄송합니다. 잠시만요. 네, 아니에요. 회의 중이라 나중에 연락드릴게요. 죄송합니다. 이어서 말씀드리면, 우리에게 가장 현실적이고 파급력 있는 전략은 '더 나은 프리미엄 파괴자'가 되는 겁니다. Fathom처럼 녹음/녹취는 관대하게 무료로 풀어서 사용자를 모으고, 그들이 정말 돈을 내고 싶어 할 만한 '팀 협업 기능'이나 '고급 AI 기능'에서 수익을 내는 거죠.
# Speaker 2: '더 나은 프리미엄 파괴자'라... 흥미로운 방향성이네요. 그럼 Fathom보다 '더 나은' 점은 뭘로 가져가야 할까요?
# Speaker 3: 보고서에 나온 '대화형 AI 챗' 기능이 강력한 무기가 될 수 있겠네요. "지난 분기에 결정된 예산안 다시 알려줘"라고 물으면 답해주는 기능이요. 이건 Fathom의 무료 플랜에는 없는 고부가가치 기능입니다. 이걸 우리 킬러 기능으로 삼는 거죠.
# Speaker 1: 좋아요! 사용자가 과거 회의록을 일일이 뒤지는 고통을 해결해줄 수 있겠네요. UX적으로도 아주 매력적인 기능이에요.
# Speaker 2: 아주 좋은 아이디어들이네요. 그럼 방향이 어느 정도 잡히는 것 같습니다. 우리의 전략적 포지션은 '더 나은 프리미엄 파괴자'로 하고, 핵심 차별점은 '강력한 AI 챗 기능'과 '매끄러운 워크플로우 통합'으로 가져가는 걸로요. 그럼 이 방향성에 맞춰 다음 회의에서는 구체적인 MVP 기능 리스트를 확정해봅시다. 보고서 3부의 '기능 구현 로드맵' 표를 기준으로 어떤 걸 넣고 뺄지 결정하죠. 다들 수고 많으셨습니다!
# [회의록 HEADER]
# Speaker 1: 다들 점심은 맛있게 드셨어요? 자, 그럼 지난번에 논의했던 '더 나은 프리미엄 파괴자' 전략을 기반으로, 오늘은 우리 제품의 MVP 스펙을 확정 짓는 중요한 날입니다. 제가 화이트보드에 보고서의 기능 로드맵 표를 그려놨어요. 여기서 MVP에 포함될 것과 아닌 것을 명확히 구분해보죠.
# Speaker 2: 우선 '녹취 엔진'은 고정확도 STT, 화자 분리. 이건 기본 중의 기본이니 당연히 들어가야 하고요. 플랫폼은 우선순위를 고려해서 '웹 앱'부터 집중하는 게 맞겠습니다. 모바일 앱은 MVP 이후 단계로 미루고요.
# Speaker 3: 동의합니다. 초기 타겟 유저들은 대부분 PC 환경에서 화상 회의를 하고 결과를 확인할 테니, 웹 앱 경험을 완벽하게 만드는 게 중요해요. Fathom도 브라우저 확장 프로그램과 웹 앱이 핵심이잖아요.
# Speaker 4: 맞아요. 그리고 'AI 인텔리전스' 파트가 제일 중요하겠네요. '기본 자동 요약'과 '실행 항목(Action Item) 감지'는 MVP에 반드시 포함되어야 해요. 이게 없으면 그냥 녹취 앱이랑 다를 게 없으니까요.
# Speaker 1: 그럼 우리가 킬러 기능으로 생각했던 '대화형 AI 챗'은 어떻게 할까요? MVP에 넣기엔 개발 공수가 좀 크지 않을까요, 수석님?
# Speaker 2: 솔직히 부담되는 건 맞습니다. 하지만 이게 우리의 핵심 차별점이라면, 아주 기본적인 버전이라도 MVP에 넣어야 한다고 생각해요. 예를 들어, 현재 보고 있는 회의록 내에서만 질문에 답해주는 수준으로 시작하는 거죠. 모든 회의록을 다 뒤지는 건 2단계로 넘기고요.
# Speaker 3: 좋은 아이디어네요. 사용자에게 '아, 이 서비스는 내 회의 내용을 이해하고 있구나!'라는 첫인상을 주는 게 중요합니다. 마케팅 관점에서도 '회의에 질문하세요'라는 메시지는 아주 강력할 겁니다.
# Speaker 1: 좋습니다. 그럼 '대화형 AI 챗 (단일 회의)' 기능은 MVP에 넣는 걸로. 서연님, '워크플로우' 쪽은요?
# Speaker 4: '링크 기반 공유'는 필수고요, 사용자가 회의를 자동으로 기록하게 하려면 '캘린더 연동(구글/아웃룩)'은 무조건 있어야 해요. 이게 없으면 사용자가 매번 수동으로 봇을 초대해야 해서 너무 불편할 거예요.
# Speaker 3: 그럼 CRM 연동이나 슬랙, 노션 같은 협업 툴 연동은요?
# Speaker 1: 그건 우리가 유료 플랜의 핵심 가치로 제공할 기능들이니 MVP에서는 제외하는 게 맞겠습니다. 우선 사용자가 우리 제품 자체의 가치를 느끼게 하는 데 집중해야죠. 정리하겠습니다. 다들 이 리스트에 동의하시나요?
# Speaker 1: 좋습니다. 그럼 이 스펙을 기준으로 개발과 디자인을 시작하죠. 정훈 수석님은 상세 기술 설계와 개발 일정 산출을, 서연 디자이너님은 MVP 기능에 대한 와이어프레임 작업을 시작해주세요. 지호 매니저님은 이 MVP를 기반으로 구체적인 시장 진출(GTM) 전략과 가격 정책 초안을 준비해주시고요. 다음 회의 땐 각자 준비한 내용을 공유하면서 로드맵을 구체화합시다.
# [회의록 HEADER]
# Speaker 1: 지난주에 정한 MVP 스펙으로 GTM 전략을 짜보니까 그림이 훨씬 명확해지더라고요. 역시 일단 뭐라도 정해야 일이 진행되는 것 같아요.
# Speaker 2: 맞아요. 다들 바쁘게 일주일을 보내셨을 텐데, 진행 상황을 한 번 들어볼까요? 서연님, 와이어프레임은 좀 어떠세요?
# Speaker 3: 네, 화면에 공유해 드릴게요. 이게 사용자가 회의를 끝내고 처음 마주하는 결과 화면이에요. 왼쪽엔 전체 스크립트, 오른쪽 상단엔 AI 요약과 Action Item, 그리고 하단에 저희의 킬러 기능인 '회의에 질문하기' 챗봇 창을 배치했어요. 사용자가 다른 화면으로 넘어가지 않고 한 곳에서 모든 정보를 확인하고 활용할 수 있도록 구성했습니다.
# Speaker 4: 오, 구조가 아주 깔끔한데요. 저 정도 UI라면 API 연동하고 데이터 뿌려주는 건 기술적으로 문제없습니다. 저도 개발 일정을 산출해봤는데, 지난번에 확정한 MVP 스펙 기준으로는 3개월 정도면 초기 버전 출시가 가능할 것 같습니다. STT 엔진은 여러 테스트를 거친 결과, 비용과 성능을 고려했을 때 OpenAI의 Whisper API를 메인으로 사용하는 것으로 결정했습니다.
# Speaker 2: 3개월이라, 아주 희망적인데요. 좋습니다. 지호 매니저님, 마케팅 쪽은요?
# Speaker 1: 가격 정책은 보고서에서 제안한 '하이브리드 프리미엄' 모델로 구체화했습니다. 핵심 녹취/요약/AI챗(단일 회의)은 월 5회까지 무료로 제공해서 사용자 유입을 유도하고, 무제한 사용과 팀 기능, 그리고 향후 추가될 CRM 연동 등은 유료 플랜으로 묶는 방식입니다. 초기 사용자 확보를 위해선 서연님이 강조했던 '공유를 통한 바이럴 루프' 설계가 매우 중요할 것 같아요.
# Speaker 2: 완벽합니다. 이제 정말 우리가 뭘 만들어야 할지, 어떻게 시장에 선보여야 할지 명확해졌네요. 그럼 오늘 회의를 통해 개발 로드맵을 최종 확정하겠습니다.
# Speaker 2: 이 로드맵대로 우리 프로젝트를 진행하겠습니다. 이제 각자 자리로 돌아가서 맡은 역할을 실행에 옮길 시간입니다. 정식 프로젝트명도 정해야 하고 할 일이 태산이지만, 이렇게 한 걸음씩 나아가면 분명 좋은 결과가 있을 겁니다. 다들 정말 수고 많으셨고, 앞으로 잘 부탁드립니다

# %% [markdown]
# ## STEP 3. 회의록 각 차수에 맞게 나눈다.

# %%
# "### **"를 기준으로 텍스트를 나눕니다.
# 첫 번째 요소는 서론이므로, 인덱스 1부터 사용합니다.
split_meetings = response.text.split("[회의록 HEADER]")[1:]

# 각 변수에 회의록 내용을 할당합니다.
meeting_1 = (
    split_meetings[0] if len(split_meetings) > 0 else "1차 회의록을 찾을 수 없습니다."
)
meeting_2 = (
    split_meetings[1] if len(split_meetings) > 1 else "2차 회의록을 찾을 수 없습니다."
)
meeting_3 = (
    split_meetings[2] if len(split_meetings) > 2 else "3차 회의록을 찾을 수 없습니다."
)
meeting_4 = (
    split_meetings[3] if len(split_meetings) > 3 else "4차 회의록을 찾을 수 없습니다."
)

# %% [markdown]
# #### 3.1 잘 나눠졌는지 확인

# %%
print(meeting_1)
# Out:
# Speaker 1: 다들 좋은 아침입니다. 주말은 잘 보내셨어요? 오늘 아침에 비가 와서 그런지 차가 엄청 막히더라고요. 지각할 뻔했습니다.
# Speaker 2: 저도요. 버스에 사람이 어찌나 많던지. 그래도 커피 한 잔 하니 정신이 좀 드네요.
# Speaker 3: 전 다행히 지하철 타고 와서 괜찮았어요. 자, 다들 커피도 있으니 시작해볼까요?
# Speaker 1: 네, 좋습니다. 오늘부터 우리가 함께 만들어갈 신규 프로젝트, 가칭 'AI 회의 인텔리전스 플랫폼'에 대한 킥오프 미팅을 시작하겠습니다. 제가 공유 드린 전략 분석 보고서는 다들 읽어보셨죠?
# Speaker 4: 네, 어제 밤에 정독했습니다. 분량이 꽤 되던데요. 시장 분석이 아주 상세해서 놀랐습니다.
# Speaker 1: 그렇죠? 보고서의 핵심 논지, '단순 녹취를 넘어 인텔리전스로의 진화'라는 말이 딱 와닿았어요. 이제 STT 정확도만으로는 승부할 수 없는 시장이 된 거죠. 우리의 목표는 단순한 받아쓰기 셔틀이 아니라, 회의에서 '통찰력'을 뽑아주는 진정한 '인텔리전스' 플랫폼을 만드는 겁니다.
# Speaker 2: 맞습니다. 특히 국내 시장 분석 파트가 인상 깊었어요. 네이버 '클로바노트'가 '한국어라는 해자(moat)'를 아주 깊게 파놓은 상황에서, 우리가 단순히 '한국어 인식이 더 정확해요'라고 외치는 건 자살행위나 다름없죠.
# Speaker 3: 저도 그 부분에 공감해요. 클로바노트를 쓰는 친구들 보면 정확도 자체에는 이미 만족하고 있더라고요. 오히려 UI가 좀 더 편했으면 좋겠다거나, 회의 끝나고 바로 할 일을 정리해줬으면 좋겠다는 식의 '워크플로우'에 대한 불만이 많았어요. 보고서에서 말하는 '인텔리전스 및 워크플로우 계층'을 우리가 어떻게 설계하느냐가 관건이겠네요.
# Speaker 4: 기술적인 관점에서도 시사하는 바가 큽니다. OpenAI의 Whisper 같은 좋은 오픈소스 모델도 있고, 클라우드 업체들 API 성능도 상향 평준화됐죠. 굳이 우리가 STT 엔진 자체를 밑바닥부터 개발하느라 리소스를 낭비할 필요가 없다는 뜻이니까요. 핵심은 변환된 텍스트를 가지고 뭘 할 거냐, 즉 후처리 로직과 AI 모델링에 집중해야 한다는 거죠.
# Speaker 1: 모두 정확히 짚어주셨습니다. 그래서 첫 회의인 오늘, 다 같이 큰 그림에 대한 공감대를 형성하고 싶었어요. 우리는 단순히 또 하나의 클로바노트 아류작을 만들려는 게 아닙니다. 클로바노트가 선점한 시장에서 우리만의 차별화된 가치를 찾아야 합니다.
# Speaker 2: 비토(VITO)가 '통화 녹음'에 집중하거나, 다글로가 '유튜브 스크립트'를 파고든 것처럼 우리도 명확한 타겟이나 틈새를 찾아야겠군요.
# Speaker 1: 맞습니다. 그래서 다음 회의 전까지 각자 고민해올 부분을 좀 드릴게요. 정훈 수석님은 보고서의 '기본 토대 기능' 파트를 중심으로, 우리가 MVP(최소 기능 제품)로 가져갈 기술 스택과 STT 엔진 선정(자체/외부 API)에 대한 장단점을 검토해주세요.
# Speaker 4: 알겠습니다. 비용과 개발 공수, 정확도 측면에서 비교 분석해보겠습니다.
# Speaker 1: 서연 디자이너님은 경쟁 서비스들, 특히 Fathom이나 tl;dv 같은 글로벌 서비스들의 UX를 좀 더 깊게 분석해주시고, 사용자가 회의록을 가지고 어떤 '워크플로우'를 거치는지에 대한 가설을 세워주세요.
# Speaker 3: 네, 좋습니다. 특히 회의 내용을 공유하고 협업하는 과정에 집중해서 들여다볼게요.
# Speaker 1: 그리고 지호 매니저님은 보고서의 '글로벌 시장' 파트와 '수익화 전략'을 중심으로, 우리가 어떤 시장 포지션을 취해야 할지, 예를 들어 '프리미엄 파괴자'가 될지, '수직적 전문가'가 될지 전략 방향성에 대한 의견을 정리해주세요.
# Speaker 2: 재밌는 과제네요. Fathom의 파격적인 무료 정책이 굉장히 인상 깊었는데, 그 비즈니스 모델을 좀 더 파봐야겠습니다.
# Speaker 1: 좋습니다. 그럼 다음 회의는 이번 주 금요일 오전에 하죠. 오늘 나온 이야기들을 바탕으로 각자 고민한 내용들을 공유하면서 구체적인 방향을 잡아봅시다. 다들 수고하셨습니다.

# %%
def save_dialogue_to_file(dialogStr, file_name):
    # 파일을 쓰기 모드('w')로 열고 내용을 작성
    with open(file_name, 'w', encoding='utf-8') as f:
        f.write(dialogStr)
    
    print(f"✅ 문자열이 '{file_name}' 파일에 성공적으로 저장되었습니다.")

save_dialogue_to_file(meeting_1, "meeting1.txt")
save_dialogue_to_file(meeting_2, "meeting2.txt")
save_dialogue_to_file(meeting_3, "meeting3.txt")
save_dialogue_to_file(meeting_4, "meeting4.txt")
# Out:
# ✅ 문자열이 'meeting1.txt' 파일에 성공적으로 저장되었습니다.
# ✅ 문자열이 'meeting2.txt' 파일에 성공적으로 저장되었습니다.
# ✅ 문자열이 'meeting3.txt' 파일에 성공적으로 저장되었습니다.
# ✅ 문자열이 'meeting4.txt' 파일에 성공적으로 저장되었습니다.

# %% [markdown]
# ### 차수로 나누어진 회의록 csv로 저장

# %%
import pandas as pd
import io
import os


# ---------------------------------------------------------------------------------
# 1. 통합 CSV 저장 함수 (텍스트 내용과 출력 파일명만 인수로 받음)
def save_to_csv(text_content, filename):

    parsed_data = []

    # 1. 텍스트 파싱 로직
    # 문자열을 파일 객체처럼 처리하여 줄 단위로 읽습니다.
    file_like_object = io.StringIO(text_content)

    for line in file_like_object:
        # 양 끝의 공백 및 개행 문자를 제거합니다.
        clean_line = line.strip()

        # 빈 줄은 건너뜀
        if not clean_line:
            continue

        # 첫 번째 ': '를 기준으로 발화자(Speaker)와 스크립트(Transcript)를 분리합니다.
        # split(': ', 1)을 사용하여 스크립트 내용에 ':'가 있어도 문제가 되지 않도록 합니다.
        parts = clean_line.split(": ", 1)

        if len(parts) == 2:
            speaker = parts[0].strip()
            transcript = parts[1].strip()

            # 파싱된 데이터를 딕셔너리 형태로 리스트에 추가
            parsed_data.append({"org_speaker": speaker, "org_transcript": transcript})
        # 형식에 맞지 않는 줄은 경고 없이 건너킵니다.

    # 파싱된 데이터를 사용하여 DataFrame 생성
    df = pd.DataFrame(parsed_data)

    # CSV 파일로 저장
    # index=False: DataFrame의 인덱스를 CSV에 포함하지 않음
    # encoding='utf-8-sig': 한글 깨짐 방지 및 엑셀 호환성을 위한 인코딩 설정
    df.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"{filename} 파일 생성 성공")

# %%
save_to_csv(meeting_1, "meeting1.csv")
save_to_csv(meeting_2, "meeting2.csv")
save_to_csv(meeting_3, "meeting3.csv")
save_to_csv(meeting_4, "meeting4.csv")
# Out:
# meeting1.csv 파일 생성 성공
# meeting2.csv 파일 생성 성공
# meeting3.csv 파일 생성 성공
# meeting4.csv 파일 생성 성공

# %% [markdown]
# ## STEP 4. 각 차수별 오디오 파일을 생성한다. (OPENAI TTS사용)

# %%
import os
import re
from openai import OpenAI
from pydub import AudioSegment
import io
from dotenv import load_dotenv

# .env 파일에서 환경변수 로드
load_dotenv()

# 모델 설정
set_model = "tts-1-hd"  # 또는 "tts-1" (더 빠르지만 품질이 낮음)

# OpenAI TTS 음성 옵션: alloy, echo, fable, onyx, nova, shimmer
set_speaker_voices = {
    "Speaker 1": "alloy",  # 중성적인 음성
    "Speaker 2": "echo",  # 남성적인 음성
    "Speaker 3": "fable",  # 영국식 억양
    "Speaker 4": "onyx",  # 깊은 남성 음성
}


def save_binary_file(file_name, data):
    """Saves binary data to a file."""
    with open(file_name, "wb") as f:
        f.write(data)
    print(f"✅ File saved successfully to: {file_name}")


def generate(conversation: str, saveFile: str):
    """
    Generates single-speaker audio for each line of dialogue and combines them
    into a single WAV file using OpenAI TTS API.
    """
    # OpenAI 클라이언트 생성
    client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

    # TTS 모델 설정
    model = set_model

    # 음성 4개 설정
    speaker_voices = set_speaker_voices

    # 대화 내용 파싱
    dialogue_blocks = conversation.strip().split("\n")
    dialogue_parts = []
    for block in dialogue_blocks:
        if block.strip():
            match = re.match(r"(Speaker \d+): (.*)", block, re.DOTALL)
            if match:
                speaker = match.group(1)
                dialogue = match.group(2)
                dialogue_parts.append({"speaker": speaker, "dialogue": dialogue})

    # 각 파트별 audio 대화를 생성
    all_audio_segments = []

    for part in dialogue_parts:
        speaker = part["speaker"]
        dialogue = part["dialogue"]
        voice_name = speaker_voices.get(speaker, "alloy")

        print(f"Generating audio for {speaker} with voice '{voice_name}'...")
        # print(dialogue)

        try:
            # OpenAI TTS API 호출
            response = client.audio.speech.create(
                model=model,
                voice=voice_name,
                input=dialogue,
                response_format="wav",  # WAV 형식으로 직접 생성
            )

            # 응답을 바이트로 읽기
            audio_data = response.content

            # pydub AudioSegment로 변환
            audio_segment = AudioSegment.from_file(io.BytesIO(audio_data), format="wav")
            all_audio_segments.append(audio_segment)
            print(" -> Success.")

        except Exception as e:
            print(f" -> Failed to generate audio for '{dialogue[:30]}...': {e}")

    # 모든 오디오 세그먼트 결합
    if all_audio_segments:
        print("\nCombining all audio parts...")
        combined_audio = all_audio_segments[0]
        for segment in all_audio_segments[1:]:
            combined_audio += segment

        # WAV 파일로 저장
        combined_audio.export(saveFile, format="wav")
        print(f"✅ Combined audio saved to: {saveFile}")
    else:
        print("No audio data was generated.")


def convert_pcm_to_wav(
    pcm_data: bytes,
    sample_rate: int = 24000,
    bits_per_sample: int = 16,
    num_channels: int = 1,
) -> bytes:
    """Converts raw PCM data to WAV format."""
    data_size = len(pcm_data)
    bytes_per_sample = bits_per_sample // 8
    block_align = num_channels * bytes_per_sample
    byte_rate = sample_rate * block_align
    chunk_size = 36 + data_size

    header = struct.pack(
        "<4sI4s4sIHHIIHH4sI",
        b"RIFF",
        chunk_size,
        b"WAVE",
        b"fmt ",
        16,  # fmt chunk size
        1,  # audio format (PCM)
        num_channels,
        sample_rate,
        byte_rate,
        block_align,
        bits_per_sample,
        b"data",
        data_size,
    )
    return header + pcm_data

# %%
WAV_FILE_NAME = "meeting2.wav"  

# 방법 1: pydub 사용 (권장)
generate(meeting_2, WAV_FILE_NAME)
# Out:
# Generating audio for Speaker 1 with voice 'alloy'...
#  -> Success.
# Generating audio for Speaker 2 with voice 'echo'...
#  -> Success.
# Generating audio for Speaker 3 with voice 'fable'...
#  -> Success.
# Generating audio for Speaker 2 with voice 'echo'...
#  -> Success.
# Generating audio for Speaker 1 with voice 'alloy'...
#  -> Success.
# Generating audio for Speaker 4 with voice 'onyx'...
#  -> Success.
# Generating audio for Speaker 4 with voice 'onyx'...
#  -> Success.
# Generating audio for Speaker 2 with voice 'echo'...
#  -> Success.
# Generating audio for Speaker 3 with voice 'fable'...
#  -> Success.
# Generating audio for Speaker 1 with voice 'alloy'...
#  -> Success.
# Generating audio for Speaker 2 with voice 'echo'...
#  -> Success.
#
# Combining all audio parts...
# ✅ Combined audio saved to: metting2.wav

# %%
#!gcloud auth application-default login
#!set GOOGLE_APPLICATION_CREDENTIALS="C:\Users\park0\AppData\Roaming\gcloud\application_default_credentials.json"

# %%
from myClovaSpeech import ClovaSpeechClient

res = ClovaSpeechClient().req_upload(
    file="meeting2.wav", completion="sync"
)
# Out:
# b'{"language": "ko-KR", "completion": "sync", "callback": null, "userdata": null, "wordAlignment": true, "fullText": true, "forbiddens": null, "boostings": null, "diarization": null, "sed": null}'

# %%
import pandas as pd

result = res.json()
#print(result)

# 화자별 인식 결과 segment 추출
segments = result.get("segments", [])
speaker_segments = []
for segment in segments:
    speaker_label = segment["speaker"]["label"]
    text = segment["text"]
    confidence = segment["confidence"]
    startTime = segment["start"]
    speaker_segments.append({"start_time": startTime, "confidence":confidence, "speaker": speaker_label, "text": text})

# %%
print(speaker_segments)
# Out:
# [{'start_time': 0, 'confidence': 0.9819, 'speaker': '1', 'text': '다들 들어오셨네요. 안녕하세요 재택근무하니 출근 시간 아껴서 너무 좋아요.'}, {'start_time': 4772, 'confidence': 0.9606, 'speaker': '2', 'text': '서연님 좋으시겠어요? 전 오늘 아이 유치원 데려다 주고 오느라 정신이 하나도 없었네요.'}, {'start_time': 10645, 'confidence': 0.9009, 'speaker': '2', 'text': '자 그럼 2차 회의 시작하겠습니다. 지난번에 각자 맡은 부분들 잘 고민해 오셨죠? 먼저 정은 수석님 STT 엔진은 어떻게 보셨어요?'}, {'start_time': 21080, 'confidence': 0.6804, 'speaker': '3', 'text': '네 결론부터 말씀드리면 MVP 단계에서는 외부 API를 활용하는 게 압도적으로 유리합니다.'}, {'start_time': 28195, 'confidence': 0.9354, 'speaker': '3', 'text': '자체 엔진 개발은 시간, 비용, 인력 모든 면에서 비효율적이에요.'}, {'start_time': 33825, 'confidence': 0.9046, 'speaker': '3', 'text': '현재로서는 오픈 AI의 위스퍼 API나 구글 네이버 클라우드의 STT API가 가장 유력한 후보입니다.'}, {'start_time': 41485, 'confidence': 0.9716, 'speaker': '3', 'text': '특히 위스퍼는 한국어 정확도도 상당히 높게 나와서 이걸 기반으로 우리만의 후처리 로직을 더하는 방향으로 가는 게 맞아 보입니다.'}, {'start_time': 49795, 'confidence': 0.7652, 'speaker': '2', 'text': '명쾌하네요. 우리 핵심은 STT 자체가 아니라 인텔리전스 계층이니까요. 좋은 판단입니다. 그럼 서연 님은 UX 분석 어떠셨어요?'}, {'start_time': 58938, 'confidence': 0.8187, 'speaker': '1', 'text': '패덤이랑 티엘디비를 직접 써봤는데 정말 감탄했어요. 그냥 회의 녹화 앱이 아니더라고요.'}, {'start_time': 65870, 'confidence': 0.9133, 'speaker': '1', 'text': '회의가 끝나자마자 자동으로 요약본이 생성되고 중요한 부분을 영상 클립으로 만들어서 바로 슬랙에 공유할 수 있는 경험이 정말 강력했어요.'}, {'start_time': 76940, 'confidence': 0.9225, 'speaker': '1', 'text': '사용자가 회의록을 정리하게 만드는 게 아니라 활용하게 만드는 데 초점을 맞춘 거죠. 우리의 워크플로우도 이 방향으로 가야 해요.'}, {'start_time': 86079, 'confidence': 0.8462, 'speaker': '1', 'text': '회의 기록 요약 실행 항목 도출, 협업 툴 연동 이 과정이 물 흐르듯 이어져야 합니다.'}, {'start_time': 93194, 'confidence': 0.9684, 'speaker': '4', 'text': '서연 님 말씀에 전적으로 동감합니다. 제가 분석한 시장 포지셔닝 전략과도 일맥상통해요. 글로벌 시장은 두 갈래로 나뉘어 있어요.'}, {'start_time': 103354, 'confidence': 0.9331, 'speaker': '4', 'text': '패덤처럼 공격적인 무료 플랜으로 시장을 장악하는 제품 주도 성장 파괴자와 건처럼 세일즈 팀에 특화된 고가 솔루션인 수직적 전문가.'}, {'start_time': 113835, 'confidence': 0.918, 'speaker': '4', 'text': '우리가 지금 꿩처럼 되기엔 특정 산업에 대한 깊이와 영업 조직이 부족합니다. 죄송합니다. 잠시만요. 네 아니에요. 회의 중이라 나중에 연락드릴게요. 죄송합니다.'}, {'start_time': 125995, 'confidence': 0.9977, 'speaker': '4', 'text': '이어서 말씀드리면 우리에게 가장 현실적이고 파급력 있는 전략은 더 나은 프리미엄 파괴자가 되는 겁니다.'}, {'start_time': 134350, 'confidence': 0.9015, 'speaker': '4', 'text': '파덤처럼 녹음 녹취는 관대하게 무료로 풀어서 사용자를 모으고 그들이 정말 돈을 내고 싶어 할 만한 팀 협업 기능이나 고급 AI 기능에서 수익을 내는 거죠.'}, {'start_time': 146355, 'confidence': 0.914, 'speaker': '2', 'text': '더 나은 프리미엄 파괴자라 흥미로운 방향성이네요. 그럼 패던보다 더 나은 점은 뭘로 가져가야 할까요?'}, {'start_time': 154595, 'confidence': 0.7192, 'speaker': '3', 'text': '보고서에 나온 대화형 AI 챗 기능이 강력한 무기가 될 수 있겠네요.'}, {'start_time': 159790, 'confidence': 0.9403, 'speaker': '3', 'text': '지난 분기에 결정된 예산안 다시 알려줘라고 물으면 답해주는 기능이요. 이건 파드메 무료 플랜은 없는 고부가가치 기능입니다.'}, {'start_time': 169785, 'confidence': 0.8303, 'speaker': '3', 'text': '이걸 우리 킬러 기능으로 삼는 거죠.'}, {'start_time': 172448, 'confidence': 0.8953, 'speaker': '1', 'text': '좋아요. 사용자가 과거 회의록을 일일이 뒤지는 고통을 해결해 줄 수 있겠네요. 유스적으로도 아주 매력적인 기능이에요.'}, {'start_time': 180312, 'confidence': 0.9566, 'speaker': '2', 'text': '아주 좋은 아이디어들이네요. 그럼 방향이 어느 정도 잡히는 것 같습니다.'}, {'start_time': 185785, 'confidence': 0.8586, 'speaker': '2', 'text': '우리의 전략적 포지션은 더 나은 프리미엄 파괴자로 하고 핵심 차별점은 강력한 AI 챗 기능과 매끄러운 워크플로우 통합으로 가져가는 걸로요.'}, {'start_time': 197470, 'confidence': 0.969, 'speaker': '2', 'text': '그럼 이 방향성에 맞춰 다음 회의에서는 구체적인 MVP 기능 리스트를 확정해 봅시다.'}, {'start_time': 203915, 'confidence': 0.9617, 'speaker': '2', 'text': '보고서 3부에 기능 구현 로드맵 표를 기준으로 어떤 걸 넣고 뺄지 결정하죠. 다들 수고 많으셨습니다.'}]

# %%
from typing import List, Dict, Any

def merge_consecutive_speaker_segments(segments: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    """연속적으로 동일한 화자의 세그먼트를 하나의 텍스트로 합칩니다."""
    if not segments:
        return []

    merged_segments = []
    
    # 첫 번째 세그먼트로 초기화
    current_segment = segments[0].copy()

    # 두 번째 세그먼트부터 순회
    for next_segment in segments[1:]:
        if current_segment['speaker'] == next_segment['speaker']:
            # 1. 화자가 동일하면, 텍스트를 합칩니다.
            current_segment['text'] += ' ' + next_segment['text']
            # start_time, confidence 등 다른 값들은 이전 세그먼트의 값을 유지합니다.
        else:
            # 2. 화자가 달라지면, 현재까지 합쳐진 세그먼트를 최종 리스트에 추가합니다.
            merged_segments.append(current_segment)
            # 3. 다음 세그먼트로 현재 세그먼트를 갱신합니다.
            current_segment = next_segment.copy()

    # 루프가 종료된 후, 마지막으로 처리 중이던 세그먼트를 최종 리스트에 추가합니다.
    merged_segments.append(current_segment)
    
    return merged_segments

# 함수 실행
merged_data = merge_consecutive_speaker_segments(speaker_segments)

# 결과 출력
import pprint
pprint.pprint(merged_data)
# Out:
# [{'confidence': 0.9819,
#   'speaker': '1',
#   'start_time': 0,
#   'text': '다들 들어오셨네요. 안녕하세요 재택근무하니 출근 시간 아껴서 너무 좋아요.'},
#  {'confidence': 0.9606,
#   'speaker': '2',
#   'start_time': 4772,
#   'text': '서연님 좋으시겠어요? 전 오늘 아이 유치원 데려다 주고 오느라 정신이 하나도 없었네요. 자 그럼 2차 회의 '
#           '시작하겠습니다. 지난번에 각자 맡은 부분들 잘 고민해 오셨죠? 먼저 정은 수석님 STT 엔진은 어떻게 보셨어요?'},
#  {'confidence': 0.6804,
#   'speaker': '3',
#   'start_time': 21080,
#   'text': '네 결론부터 말씀드리면 MVP 단계에서는 외부 API를 활용하는 게 압도적으로 유리합니다. 자체 엔진 개발은 시간, '
#           '비용, 인력 모든 면에서 비효율적이에요. 현재로서는 오픈 AI의 위스퍼 API나 구글 네이버 클라우드의 STT API가 '
#           '가장 유력한 후보입니다. 특히 위스퍼는 한국어 정확도도 상당히 높게 나와서 이걸 기반으로 우리만의 후처리 로직을 더하는 '
#           '방향으로 가는 게 맞아 보입니다.'},
#  {'confidence': 0.7652,
#   'speaker': '2',
#   'start_time': 49795,
#   'text': '명쾌하네요. 우리 핵심은 STT 자체가 아니라 인텔리전스 계층이니까요. 좋은 판단입니다. 그럼 서연 님은 UX 분석 '
#           '어떠셨어요?'},
#  {'confidence': 0.8187,
#   'speaker': '1',
#   'start_time': 58938,
#   'text': '패덤이랑 티엘디비를 직접 써봤는데 정말 감탄했어요. 그냥 회의 녹화 앱이 아니더라고요. 회의가 끝나자마자 자동으로 '
#           '요약본이 생성되고 중요한 부분을 영상 클립으로 만들어서 바로 슬랙에 공유할 수 있는 경험이 정말 강력했어요. 사용자가 '
#           '회의록을 정리하게 만드는 게 아니라 활용하게 만드는 데 초점을 맞춘 거죠. 우리의 워크플로우도 이 방향으로 가야 해요. '
#           '회의 기록 요약 실행 항목 도출, 협업 툴 연동 이 과정이 물 흐르듯 이어져야 합니다.'},
#  {'confidence': 0.9684,
#   'speaker': '4',
#   'start_time': 93194,
#   'text': '서연 님 말씀에 전적으로 동감합니다. 제가 분석한 시장 포지셔닝 전략과도 일맥상통해요. 글로벌 시장은 두 갈래로 나뉘어 '
#           '있어요. 패덤처럼 공격적인 무료 플랜으로 시장을 장악하는 제품 주도 성장 파괴자와 건처럼 세일즈 팀에 특화된 고가 '
#           '솔루션인 수직적 전문가. 우리가 지금 꿩처럼 되기엔 특정 산업에 대한 깊이와 영업 조직이 부족합니다. 죄송합니다. '
#           '잠시만요. 네 아니에요. 회의 중이라 나중에 연락드릴게요. 죄송합니다. 이어서 말씀드리면 우리에게 가장 현실적이고 파급력 '
#           '있는 전략은 더 나은 프리미엄 파괴자가 되는 겁니다. 파덤처럼 녹음 녹취는 관대하게 무료로 풀어서 사용자를 모으고 그들이 '
#           '정말 돈을 내고 싶어 할 만한 팀 협업 기능이나 고급 AI 기능에서 수익을 내는 거죠.'},
#  {'confidence': 0.914,
#   'speaker': '2',
#   'start_time': 146355,
#   'text': '더 나은 프리미엄 파괴자라 흥미로운 방향성이네요. 그럼 패던보다 더 나은 점은 뭘로 가져가야 할까요?'},
#  {'confidence': 0.7192,
#   'speaker': '3',
#   'start_time': 154595,
#   'text': '보고서에 나온 대화형 AI 챗 기능이 강력한 무기가 될 수 있겠네요. 지난 분기에 결정된 예산안 다시 알려줘라고 물으면 '
#           '답해주는 기능이요. 이건 파드메 무료 플랜은 없는 고부가가치 기능입니다. 이걸 우리 킬러 기능으로 삼는 거죠.'},
#  {'confidence': 0.8953,
#   'speaker': '1',
#   'start_time': 172448,
#   'text': '좋아요. 사용자가 과거 회의록을 일일이 뒤지는 고통을 해결해 줄 수 있겠네요. 유스적으로도 아주 매력적인 기능이에요.'},
#  {'confidence': 0.9566,
#   'speaker': '2',
#   'start_time': 180312,
#   'text': '아주 좋은 아이디어들이네요. 그럼 방향이 어느 정도 잡히는 것 같습니다. 우리의 전략적 포지션은 더 나은 프리미엄 '
#           '파괴자로 하고 핵심 차별점은 강력한 AI 챗 기능과 매끄러운 워크플로우 통합으로 가져가는 걸로요. 그럼 이 방향성에 맞춰 '
#           '다음 회의에서는 구체적인 MVP 기능 리스트를 확정해 봅시다. 보고서 3부에 기능 구현 로드맵 표를 기준으로 어떤 걸 '
#           '넣고 뺄지 결정하죠. 다들 수고 많으셨습니다.'}]

# %%
import json
import pandas as pd
import os
from typing import Optional, Dict, Any, List


def csv_append(dialogList: list, csv_filename: str) -> Optional[pd.DataFrame]:

    df_json = pd.DataFrame(dialogList)

    # 새로 추가할 컬럼만 선택
    df_new_columns = df_json[["start_time", "confidence", "speaker", "text"]]

    # --- 2. 기존 CSV 파일 불러오기 ---
    if not os.path.exists(csv_filename):
        print(
            f"[오류] '{csv_filename}' 파일이 존재하지 않습니다. 기존 파일을 확인해 주세요."
        )
        return None

    df_existing = pd.read_csv(csv_filename)

    # --- 3. 컬럼 추가 및 저장 ---
    # 기존 데이터프레임에 새로 생성한 컬럼을 병합 (axis=1은 가로 방향 병합)
    # index가 동일하다고 가정합니다.
    df_updated = pd.concat([df_existing, df_new_columns], axis=1, join="outer")

    # 수정된 DataFrame을 CSV 파일로 저장 (기존 파일 덮어쓰기)
    df_updated.to_csv(csv_filename, index=False, encoding="utf-8-sig")

    print(
        f"\n성공적으로 '{csv_filename}' 파일에 'start_time' 컬럼이 추가되고 저장되었습니다."
    )
    return df_updated

# %% [markdown]
# ### TTS에 사용한 대화 스크립트를 먼저 CSV에 저장

# %%
# CSV 파일명 설정
csv_filename = "meeting2.csv"

# 통합 함수 호출 (텍스트 내용 직접 전달)
save_to_csv(meeting_2, csv_filename)
# Out:
# meeting2.csv 파일 생성 성공

# %% [markdown]
# ### STT에서 생성된 대화 스크립트를 CSV에 추가

# %%
# csv_filename = "meeting1.csv"
updated_df = csv_append(merged_data, csv_filename)
# Out:
# 성공적으로 'meeting2.csv' 파일에 'start_time' 컬럼이 추가되고 저장되었습니다.

# %% [markdown]
# ### 컬럼 내용 전처리 및 비교

# %%
# 'org_speaker' 컬럼이 이미 DataFrame 'df_updated'에 존재한다고 가정합니다.
# 이 컬럼의 모든 값에서 "speaker" 문자열을 제거합니다.
updated_df["org_speaker"] = updated_df["org_speaker"].str.replace(
    "Speaker", "", regex=False
)
updated_df = updated_df.fillna("0")
updated_df["org_speaker"] = updated_df["org_speaker"].astype(int)
updated_df["speaker"] = updated_df["speaker"].astype(int)

updated_df.head(20)
# Out:
#     org_speaker                                     org_transcript start_time  \
# 0             1         다들 들어오셨네요. 안녕하세요! 재택근무하니 출근 시간 아껴서 너무 좋아요.        0.0
# 1             2  서연님 좋으시겠어요. 전 오늘 아이 유치원 데려다주고 오느라 정신이 하나도 없었네요...     4772.0
# 2             3  네, 결론부터 말씀드리면 MVP 단계에서는 외부 API를 활용하는 게 압도적으로 유...    21080.0
# 3             2  명쾌하네요. 우리 핵심은 STT 자체가 아니라 인텔리전스 계층이니까요. 좋은 판단입...    49795.0
# 4             1  Fathom이랑 tl;dv를 직접 써봤는데, 정말 감탄했어요. 그냥 '회의 녹화 앱...    58938.0
# 5             4  서연님 말씀에 전적으로 동감합니다. 제가 분석한 시장 포지셔닝 전략과도 일맥상통해요...    93194.0
# 6             4  어, 죄송합니다. 잠시만요. 네, 아니에요. 회의 중이라 나중에 연락드릴게요. .....   146355.0
# 7             2  '더 나은 프리미엄 파괴자'라... 흥미로운 방향성이네요. 그럼 Fathom보다 '...   154595.0
# 8             3  보고서에 나온 '대화형 AI 챗' 기능이 강력한 무기가 될 수 있겠네요. "지난 분...   172448.0
# 9             1  좋아요! 사용자가 과거 회의록을 일일이 뒤지는 고통을 해결해줄 수 있겠네요. UX적...   180312.0
# 10            2  아주 좋은 아이디어들이네요. 그럼 방향이 어느 정도 잡히는 것 같습니다. 우리의 전...          0
#
#    confidence  speaker                                               text
# 0      0.9819        1          다들 들어오셨네요. 안녕하세요 재택근무하니 출근 시간 아껴서 너무 좋아요.
# 1      0.9606        2  서연님 좋으시겠어요? 전 오늘 아이 유치원 데려다 주고 오느라 정신이 하나도 없었네...
# 2      0.6804        3  네 결론부터 말씀드리면 MVP 단계에서는 외부 API를 활용하는 게 압도적으로 유리...
# 3      0.7652        2  명쾌하네요. 우리 핵심은 STT 자체가 아니라 인텔리전스 계층이니까요. 좋은 판단입...
# 4      0.8187        1  패덤이랑 티엘디비를 직접 써봤는데 정말 감탄했어요. 그냥 회의 녹화 앱이 아니더라고...
# 5      0.9684        4  서연 님 말씀에 전적으로 동감합니다. 제가 분석한 시장 포지셔닝 전략과도 일맥상통해...
# 6       0.914        2  더 나은 프리미엄 파괴자라 흥미로운 방향성이네요. 그럼 패던보다 더 나은 점은 뭘로...
# 7      0.7192        3  보고서에 나온 대화형 AI 챗 기능이 강력한 무기가 될 수 있겠네요. 지난 분기에 ...
# 8      0.8953        1  좋아요. 사용자가 과거 회의록을 일일이 뒤지는 고통을 해결해 줄 수 있겠네요. 유스...
# 9      0.9566        2  아주 좋은 아이디어들이네요. 그럼 방향이 어느 정도 잡히는 것 같습니다. 우리의 전...
# 10          0        0                                                  0

# %%
updated_df.to_csv(csv_filename, index=False, encoding="utf-8-sig")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
